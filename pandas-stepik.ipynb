# %%
# pip install pandas numpy matplotlib --break-system-packages

# %%
import pandas as pd
import numpy as np

# %%
d1 = pd.read_csv('/home/solleks/Downloads/csv-files/coffee-shop.csv')
d2 = pd.read_csv('/home/solleks/Downloads/csv-files/coffee-shop2.csv')

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3636 entries, 0 to 3635
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3636 non-null   object
#  1   datetime     3636 non-null   object
#  2   cash_type    3636 non-null   object
#  3   card         3547 non-null   object
#  4   money        3636 non-null   float64
#  5   coffee_name  3636 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 170.6+ KB

# %%
d2
# Out:
#            date             datetime cash_type  money  \
# 0    2025-02-08  2025-02-08 14:26:04      cash   15.0
# 1    2025-02-08  2025-02-08 14:28:26      cash   15.0
# 2    2025-02-08  2025-02-08 14:33:04      card   20.0
# 3    2025-02-08  2025-02-08 15:51:04      card   30.0
# 4    2025-02-08  2025-02-08 16:35:01      cash   27.0
# ..          ...                  ...       ...    ...
# 257  2025-03-23  2025-03-23 14:55:46      cash   30.0
# 258  2025-03-23  2025-03-23 15:15:36      card   25.0
# 259  2025-03-23  2025-03-23 17:59:25      card   28.0
# 260  2025-03-23  2025-03-23 18:01:33      card   28.0
# 261  2025-03-23  2025-03-23 21:23:11      card   29.0
#
#                     coffee_name
# 0                           Tea
# 1                           Tea
# 2                      Espresso
# 3         Chocolate with coffee
# 4           Chocolate with milk
# ..                          ...
# 257                  Cappuccino
# 258               Irish whiskey
# ...

# %% [markdown]
# # Use concat() to concatenate two tables

# %%
data = pd.concat([d1, d2])
data
# Out:
#            date                 datetime cash_type                 card  \
# 0    2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001
# 1    2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002
# 2    2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002
# 3    2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003
# 4    2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004
# ..          ...                      ...       ...                  ...
# 257  2025-03-23      2025-03-23 14:55:46      cash                  NaN
# 258  2025-03-23      2025-03-23 15:15:36      card                  NaN
# 259  2025-03-23      2025-03-23 17:59:25      card                  NaN
# 260  2025-03-23      2025-03-23 18:01:33      card                  NaN
# 261  2025-03-23      2025-03-23 21:23:11      card                  NaN
#
#      money                 coffee_name
# 0     38.7                       Latte
# ...

# %% [markdown]
# ### Drop one column after concatenating

# %%
data = data.drop(columns=['card'])

# %%
data
# Out:
#            date                 datetime cash_type  money  \
# 0    2024-03-01  2024-03-01 10:15:50.520      card   38.7
# 1    2024-03-01  2024-03-01 12:19:22.539      card   38.7
# 2    2024-03-01  2024-03-01 12:20:18.089      card   38.7
# 3    2024-03-01  2024-03-01 13:46:33.006      card   28.9
# 4    2024-03-01  2024-03-01 13:48:14.626      card   38.7
# ..          ...                      ...       ...    ...
# 257  2025-03-23      2025-03-23 14:55:46      cash   30.0
# 258  2025-03-23      2025-03-23 15:15:36      card   25.0
# 259  2025-03-23      2025-03-23 17:59:25      card   28.0
# 260  2025-03-23      2025-03-23 18:01:33      card   28.0
# 261  2025-03-23      2025-03-23 21:23:11      card   29.0
#
#                     coffee_name
# 0                         Latte
# 1                 Hot Chocolate
# 2                 Hot Chocolate
# 3                     Americano
# 4                         Latte
# ..                          ...
# 257                  Cappuccino
# ...

# %%
data['coffee_name'].value_counts()
# Out:
# coffee_name
# Americano with Milk           824
# Latte                         806
# Americano                     593
# Cappuccino                    517
# Cortado                       292
# Hot Chocolate                 282
# Cocoa                         243
# Espresso                      152
# Americano with milk            44
# Irish whiskey                  21
# Tea                            16
# Coffee with Irish whiskey      16
# Irish whiskey with milk        15
# Chocolate with milk            12
# Double Irish whiskey           12
# Caramel with Irish whiskey      8
# Super chocolate                 6
# Mochaccino                      5
# Chocolate with coffee           5
# Irish with chocolate            5
# Caramel with chocolate          4
# Vanilla with Irish whiskey      3
# Caramel with milk               3
# Double espresso with milk       2
# Double vanilla                  2
# Caramel coffee                  2
# Double ristretto                1
# ...

# %%
data['id'] = range(1, len(data) + 1)
data
# Out:
#            date                 datetime cash_type  money  \
# 0    2024-03-01  2024-03-01 10:15:50.520      card   38.7
# 1    2024-03-01  2024-03-01 12:19:22.539      card   38.7
# 2    2024-03-01  2024-03-01 12:20:18.089      card   38.7
# 3    2024-03-01  2024-03-01 13:46:33.006      card   28.9
# 4    2024-03-01  2024-03-01 13:48:14.626      card   38.7
# ..          ...                      ...       ...    ...
# 257  2025-03-23      2025-03-23 14:55:46      cash   30.0
# 258  2025-03-23      2025-03-23 15:15:36      card   25.0
# 259  2025-03-23      2025-03-23 17:59:25      card   28.0
# 260  2025-03-23      2025-03-23 18:01:33      card   28.0
# 261  2025-03-23      2025-03-23 21:23:11      card   29.0
#
#                     coffee_name    id
# 0                         Latte     1
# 1                 Hot Chocolate     2
# 2                 Hot Chocolate     3
# 3                     Americano     4
# 4                         Latte     5
# ...

# %%
# gpt gave me this bad method.
cols = ['id'] + [col for col in data.columns if col != 'id']
data = data[cols]

# %%
#But there is a better way to insert a column at the beginning
data.insert(0, 'id', range(1, len(data) + 1))

# %%
data.to_csv('/home/solleks/Downloads/csv-files/coffee-shop-sales-psql.csv', index=False)

# %%
data=data.drop(columns=['id'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3898 entries, 0 to 261
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           3898 non-null   int64
#  1   date         3898 non-null   object
#  2   datetime     3898 non-null   object
#  3   cash_type    3898 non-null   object
#  4   money        3898 non-null   float64
#  5   coffee_name  3898 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 213.2+ KB
