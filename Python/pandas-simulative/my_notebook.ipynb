# %%
import pandas as pd

# %%
df = pd.read_csv("data/data.csv", encoding="1251")
dff = df

# %%
df.head(3)
# Out:
#        DR_Dat    DR_Tim  DR_NChk  DR_NDoc  DR_Apt  DR_Kkm  \
# 0  2022-08-11  10:15:35     2173  2004598       2   22577
# 1  2022-08-11  10:27:46     2174  2004598       2   22577
# 2  2022-08-11  10:27:46     2174  2004598       2   22577
#
#                 DR_TDoc  DR_TPay  DR_CDrugs  \
# 0  Розничная реализация       18      45399
# 1  Розничная реализация       15     261519
# 2  Розничная реализация       15     460864
#
#                                            DR_NDrugs        DR_Suppl  \
# 0  ЦИПРОЛЕТ 3МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП. /Д-...  Катрен г.Химки
# 1            ПЕРЕКИСЬ ВОДОРОДА 3% 100МЛ. №40 Р-Р ФЛ.  Катрен г.Химки
# 2  СОФЬЯ ГЕЛЬ Д/НОГ ВЕНОТОНИЗ. ТРОКСЕРУТИН ФОРТЕ ...  Катрен г.Химки
#
#                                     DR_Prod  DR_Kol  DR_CZak  DR_CRoz  \
# 0  Д-р Редди с Лабораторис Лтд / Dr.REDDY's    1.00    41.08    51.00
# 1                         ФЛОРА КАВКАЗА ОАО    1.00    18.61    31.00
# ...

# %%
pd.set_option("display.max_columns", 40)

# %%
pd.set_option("display.float_format", "{:.2f}".format)

# %%
df.dtypes
# Out:
# DR_Dat         object
# DR_Tim         object
# DR_NChk         int64
# DR_NDoc         int64
# DR_Apt          int64
# DR_Kkm          int64
# DR_TDoc        object
# DR_TPay         int64
# DR_CDrugs       int64
# DR_NDrugs      object
# DR_Suppl       object
# DR_Prod        object
# DR_Kol        float64
# DR_CZak       float64
# DR_CRoz       float64
# DR_SDisc      float64
# DR_CDisc      float64
# DR_BCDisc     float64
# DR_TabEmpl      int64
# DR_VZak         int64
# DR_Pos        float64
# dtype: object

# %%
df.shape
# Out:
# (4462, 21)

# %%
df.size
# Out:
# 93702

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4462, step=1)

# %%
df.columns
# Out:
# Index(['DR_Dat', 'DR_Tim', 'DR_NChk', 'DR_NDoc', 'DR_Apt', 'DR_Kkm', 'DR_TDoc',
#        'DR_TPay', 'DR_CDrugs', 'DR_NDrugs', 'DR_Suppl', 'DR_Prod', 'DR_Kol',
#        'DR_CZak', 'DR_CRoz', 'DR_SDisc', 'DR_CDisc', 'DR_BCDisc', 'DR_TabEmpl',
#        'DR_VZak', 'DR_Pos'],
#       dtype='object')

# %%
our_cols = [
    "DR_Dat",
    "DR_Tim",
    "DR_NChk",
    "DR_NDoc",
    "DR_Apt",
    "DR_NDrugs",
    "DR_Kol",
    "DR_CZak",
    "DR_CRoz",
    "DR_SDisc",
    "DR_TPay",
    "DR_CDrugs",
    "DR_Suppl",
    "DR_CDisc",
    "DR_BCDisc",
    "DR_TabEmpl",
    "DR_VZak",
    "DR_Pos",
]

# %%
df = df[our_cols]

# %%
df.shape
# Out:
# (4462, 18)

# %%
df.head()
# Out:
#        DR_Dat    DR_Tim  DR_NChk  DR_NDoc  DR_Apt  \
# 0  2022-08-11  10:15:35     2173  2004598       2
# 1  2022-08-11  10:27:46     2174  2004598       2
# 2  2022-08-11  10:27:46     2174  2004598       2
# 3  2022-08-11  10:27:46     2174  2004598       2
# 4  2022-08-11  10:33:56     2175  2004598       2
#
#                                            DR_NDrugs  DR_Kol  DR_CZak  \
# 0  ЦИПРОЛЕТ 3МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП. /Д-...    1.00    41.08
# 1            ПЕРЕКИСЬ ВОДОРОДА 3% 100МЛ. №40 Р-Р ФЛ.    1.00    18.61
# 2  СОФЬЯ ГЕЛЬ Д/НОГ ВЕНОТОНИЗ. ТРОКСЕРУТИН ФОРТЕ ...    1.00   132.69
# 3  СОФЬЯ ГХК КРЕМ Д/ТЕЛА ХОНДРОИТИН+ГЛЮКОЗАМИН 12...    1.00   133.65
# 4                   ГАЛВУС 50МГ. №28 ТАБ. /НОВАРТИС/    1.00   709.95
#
#    DR_CRoz  DR_SDisc  DR_TPay  DR_CDrugs        DR_Suppl  DR_CDisc  \
# 0    51.00     12.00       18      45399  Катрен г.Химки    925.00
# 1    31.00      3.00       15     261519  Катрен г.Химки      9.00
# ...

# %%
df.columns = [
    "date",
    "c_time",
    "nchk",
    "ndoc",
    "art",
    "drug",
    "kol",
    "zak",
    "roz",
    "disc",
    "pay_type",
    "drug_id",
    "suppl",
    "disc_id",
    "disc_barcode",
    "empl",
    "vzak",
    "pos",
]

# %%
df
# Out:
#             date    c_time  nchk      ndoc  art  \
# 0     2022-08-11  10:15:35  2173   2004598    2
# 1     2022-08-11  10:27:46  2174   2004598    2
# 2     2022-08-11  10:27:46  2174   2004598    2
# 3     2022-08-11  10:27:46  2174   2004598    2
# 4     2022-08-11  10:33:56  2175   2004598    2
# ...          ...       ...   ...       ...  ...
# 4457  2022-08-12  21:40:17  5690  18002542   18
# 4458  2022-08-12  21:40:59  5691  18002542   18
# 4459  2022-08-12  21:43:48  5692  18002542   18
# 4460  2022-08-12  21:44:46  5693  18002542   18
# 4461  2022-08-12  21:46:08  5694  18002542   18
#
#                                                    drug  kol    zak    roz  \
# 0     ЦИПРОЛЕТ 3МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП. /Д-... 1.00  41.08  51.00
# 1               ПЕРЕКИСЬ ВОДОРОДА 3% 100МЛ. №40 Р-Р ФЛ. 1.00  18.61  31.00
# 2     СОФЬЯ ГЕЛЬ Д/НОГ ВЕНОТОНИЗ. ТРОКСЕРУТИН ФОРТЕ ... 1.00 132.69 209.00
# 3     СОФЬЯ ГХК КРЕМ Д/ТЕЛА ХОНДРОИТИН+ГЛЮКОЗАМИН 12... 1.00 133.65 210.00
# ...

# %%
df["disc_barcode"] = df["disc_barcode"].astype("str").replace("\.0", "", regex=True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# /tmp/ipykernel_9534/269562976.py:1: SyntaxWarning: invalid escape sequence '\.'
#   df["disc_barcode"] = df["disc_barcode"].astype("str").replace("\.0", "", regex=True)
# /tmp/ipykernel_9534/269562976.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["disc_barcode"] = df["disc_barcode"].astype("str").replace("\.0", "", regex=True)

# %%
df["disc_id"] = df["disc_id"].astype("str").replace("\.0", "", regex=True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# /tmp/ipykernel_9534/2412157697.py:1: SyntaxWarning: invalid escape sequence '\.'
#   df["disc_id"] = df["disc_id"].astype("str").replace("\.0", "", regex=True)
# /tmp/ipykernel_9534/2412157697.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["disc_id"] = df["disc_id"].astype("str").replace("\.0", "", regex=True)

# %%
df.dtypes
# Out:
# date             object
# c_time           object
# nchk              int64
# ndoc              int64
# art               int64
# drug             object
# kol             float64
# zak             float64
# roz             float64
# disc            float64
# pay_type          int64
# drug_id           int64
# suppl            object
# disc_id          object
# disc_barcode     object
# empl              int64
# vzak              int64
# pos             float64
# dtype: object

# %% [markdown]
# change the date format

# %%
df["date"] = pd.to_datetime(df["date"]).dt.strftime("%d.%m.%Y")
# Out:
# /tmp/ipykernel_9534/2802199597.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["date"] = pd.to_datetime(df["date"]).dt.strftime("%d.%m.%Y")

# %%
df
# Out:
#             date    c_time  nchk      ndoc  art  \
# 0     11.08.2022  10:15:35  2173   2004598    2
# 1     11.08.2022  10:27:46  2174   2004598    2
# 2     11.08.2022  10:27:46  2174   2004598    2
# 3     11.08.2022  10:27:46  2174   2004598    2
# 4     11.08.2022  10:33:56  2175   2004598    2
# ...          ...       ...   ...       ...  ...
# 4457  12.08.2022  21:40:17  5690  18002542   18
# 4458  12.08.2022  21:40:59  5691  18002542   18
# 4459  12.08.2022  21:43:48  5692  18002542   18
# 4460  12.08.2022  21:44:46  5693  18002542   18
# 4461  12.08.2022  21:46:08  5694  18002542   18
#
#                                                    drug  kol    zak    roz  \
# 0     ЦИПРОЛЕТ 3МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП. /Д-... 1.00  41.08  51.00
# 1               ПЕРЕКИСЬ ВОДОРОДА 3% 100МЛ. №40 Р-Р ФЛ. 1.00  18.61  31.00
# 2     СОФЬЯ ГЕЛЬ Д/НОГ ВЕНОТОНИЗ. ТРОКСЕРУТИН ФОРТЕ ... 1.00 132.69 209.00
# 3     СОФЬЯ ГХК КРЕМ Д/ТЕЛА ХОНДРОИТИН+ГЛЮКОЗАМИН 12... 1.00 133.65 210.00
# ...

# %%
df["vzak"].unique()
# Out:
# array([1, 2])

# %%
df["vzak"] = df["vzak"].astype("str").replace("1", "Обычный").replace("2", "Интернет")
# Out:
# /tmp/ipykernel_9534/1598955680.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["vzak"] = df["vzak"].astype("str").replace("1", "Обычный").replace("2", "Интернет")

# %%
df
# Out:
#             date    c_time  nchk      ndoc  art  \
# 0     11.08.2022  10:15:35  2173   2004598    2
# 1     11.08.2022  10:27:46  2174   2004598    2
# 2     11.08.2022  10:27:46  2174   2004598    2
# 3     11.08.2022  10:27:46  2174   2004598    2
# 4     11.08.2022  10:33:56  2175   2004598    2
# ...          ...       ...   ...       ...  ...
# 4457  12.08.2022  21:40:17  5690  18002542   18
# 4458  12.08.2022  21:40:59  5691  18002542   18
# 4459  12.08.2022  21:43:48  5692  18002542   18
# 4460  12.08.2022  21:44:46  5693  18002542   18
# 4461  12.08.2022  21:46:08  5694  18002542   18
#
#                                                    drug  kol    zak    roz  \
# 0     ЦИПРОЛЕТ 3МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП. /Д-... 1.00  41.08  51.00
# 1               ПЕРЕКИСЬ ВОДОРОДА 3% 100МЛ. №40 Р-Р ФЛ. 1.00  18.61  31.00
# 2     СОФЬЯ ГЕЛЬ Д/НОГ ВЕНОТОНИЗ. ТРОКСЕРУТИН ФОРТЕ ... 1.00 132.69 209.00
# 3     СОФЬЯ ГХК КРЕМ Д/ТЕЛА ХОНДРОИТИН+ГЛЮКОЗАМИН 12... 1.00 133.65 210.00
# ...

# %% [markdown]
# ### Check for NULL values. Use any for looking by a column

# %%
df.isna().any()
# Out:
# date            False
# c_time          False
# nchk            False
# ndoc            False
# art             False
# drug            False
# kol             False
# zak             False
# roz             False
# disc            False
# pay_type        False
# drug_id         False
# suppl           False
# disc_id         False
# disc_barcode    False
# empl            False
# vzak            False
# pos             False
# dtype: bool

# %%
dff.isna().any()
# Out:
# DR_Dat        False
# DR_Tim        False
# DR_NChk       False
# DR_NDoc       False
# DR_Apt        False
# DR_Kkm        False
# DR_TDoc       False
# DR_TPay       False
# DR_CDrugs     False
# DR_NDrugs     False
# DR_Suppl      False
# DR_Prod       False
# DR_Kol        False
# DR_CZak       False
# DR_CRoz       False
# DR_SDisc      False
# DR_CDisc       True
# DR_BCDisc      True
# DR_TabEmpl    False
# DR_VZak       False
# DR_Pos        False
# dtype: bool

# %%
dff.fillna(0).isna().any()
# Out:
# DR_Dat        False
# DR_Tim        False
# DR_NChk       False
# DR_NDoc       False
# DR_Apt        False
# DR_Kkm        False
# DR_TDoc       False
# DR_TPay       False
# DR_CDrugs     False
# DR_NDrugs     False
# DR_Suppl      False
# DR_Prod       False
# DR_Kol        False
# DR_CZak       False
# DR_CRoz       False
# DR_SDisc      False
# DR_CDisc      False
# DR_BCDisc     False
# DR_TabEmpl    False
# DR_VZak       False
# DR_Pos        False
# dtype: bool

# %%
df3 = dff[dff.isna().values.any(axis=1)] # select only those lines where there is at least 1 NULL

# %% [markdown]
# ## Fill nulls with specified value

# %%
df3.fillna(0)
# Out:
#           DR_Dat    DR_Tim  DR_NChk   DR_NDoc  DR_Apt  DR_Kkm  \
# 15    2022-08-11  11:00:23     2178   2004598       2   22577
# 16    2022-08-11  11:00:23     2178   2004598       2   22577
# 20    2022-08-11  11:31:34     2181   2004598       2   22577
# 21    2022-08-11  11:31:34     2181   2004598       2   22577
# 22    2022-08-11  11:36:05     2182   2004598       2   22577
# ...          ...       ...      ...       ...     ...     ...
# 4456  2022-08-12  21:39:23     5689  18002542      18    9907
# 4457  2022-08-12  21:40:17     5690  18002542      18    9907
# 4458  2022-08-12  21:40:59     5691  18002542      18    9907
# 4459  2022-08-12  21:43:48     5692  18002542      18    9907
# 4460  2022-08-12  21:44:46     5693  18002542      18    9907
#
#                    DR_TDoc  DR_TPay  DR_CDrugs  \
# 15    Розничная реализация       18     496504
# 16    Розничная реализация       18     496504
# 20    Розничная реализация       18      14120
# ...

# %% [markdown]
# ### Interpolation

# %%
dff['DR_BCDisc'].interpolate(method='cubic')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Desktop/Data-Analyst-Portfolio/.venv/lib/python3.13/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File ~/.local/share/uv/python/cpython-3.13.3-linux-x86_64-gnu/lib/python3.13/importlib/__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'scipy'
#
# ...

# %%
dff.shape
# Out:
# (4462, 21)

# %%
dff.dropna().shape # delete records that have NULL in them
# Out:
# (1765, 21)

# %%
dff.dropna(axis=1).shape # delete COLUMNS which have at least one NULL
# Out:
# (4462, 19)
