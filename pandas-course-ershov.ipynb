# %%
import sys

print(sys.executable)
# Out:
# /home/solleks/Desktop/Data-Analyst-Portfolio/.venv/bin/python

# %% [markdown]
# ### Import libs

# %%
import pandas as pd

# %%
df = pd.read_csv(
    "https://raw.githubusercontent.com/jorisvandenbossche/pandas-tutorial/master/data/titanic.csv"
)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### write to csv

# %%
df.to_csv("./tmp.csv")

# %% [markdown]
# ### info and analysis of data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### size of the datasest

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# ### describe() shows a quick statistic summary of your data:

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### return columns

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.tail(2)
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 889          890         1       1  Behr, Mr. Karl Howell  male  26.0      0
# 890          891         0       3    Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 889      0  111369  30.00  C148        C
# 890      0  370376   7.75   NaN        Q

# %% [markdown]
# ### dtypes return all columns data types

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ### Getitem ([])
#
# For a DataFrame, passing a single label selects a columns and yields a **Series** equivalent to df.A:

# %%
df["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# ### **Series** is a data structure that is used to store 1D array (odnomerniy massiv)

# %%
type(df["Name"])  # returns Series obj
# Out:
# pandas.core.series.Series

# %%
df["Name"].shape
# Out:
# (891,)

# %% [markdown]
# ### Sampling by columns
# use array inside of array in any order

# %%
df[["Sex", "Name", "Age"]]
# Out:
#         Sex                                               Name   Age
# 0      male                            Braund, Mr. Owen Harris  22.0
# 1    female  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2    female                             Heikkinen, Miss. Laina  26.0
# 3    female       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4      male                           Allen, Mr. William Henry  35.0
# ..      ...                                                ...   ...
# 886    male                              Montvila, Rev. Juozas  27.0
# 887  female                       Graham, Miss. Margaret Edith  19.0
# 888  female           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889    male                              Behr, Mr. Karl Howell  26.0
# 890    male                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 3 columns]

# %% [markdown]
# ### Sampling by columns and rows using tail() or head()

# %%
df[["Name", "Age", "Sex"]].head(3)
# Out:
#                                                 Name   Age     Sex
# 0                            Braund, Mr. Owen Harris  22.0    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                             Heikkinen, Miss. Laina  26.0  female

# %% [markdown]
# ### Sampling by columns AND rows using **loc() iloc()**
#
# loc workes with column names and with index values. e.g [[index], ['value']]

# %%
df.loc[[5, 10, 15], ["Name", "Age", "Survived"]]
# Out:
#                                 Name   Age  Survived
# 5                   Moran, Mr. James   NaN         0
# 10   Sandstrom, Miss. Marguerite Rut   4.0         1
# 15  Hewlett, Mrs. (Mary D Kingcome)   55.0         1

# %% [markdown]
# ### Sampling by COLUMN ORDER AND INDEX ORDER
#
# Основное различие между этими двумя методами заключается в том, что iloc применяется для обращения по численному индексу, тогда как loc используется для обращения по метке (label).
#
# в loc можно обращаться по значению, а в iloc только по целочисоенному индексу

# %%
df.iloc[[5, 10, 15], [0, 3, 5, 1]]
# Out:
#     PassengerId                              Name   Age  Survived
# 5             6                  Moran, Mr. James   NaN         0
# 10           11   Sandstrom, Miss. Marguerite Rut   4.0         1
# 15           16  Hewlett, Mrs. (Mary D Kingcome)   55.0         1

# %% [markdown]
# ### In pandas, you should use the bitwise & operator for element-wise logical operations. Additionally, you need to wrap each condition in parentheses.

# %%
df[(df["Age"] < 18) & (df["Survived"] == 0)]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# 24            25         0       3            Palsson, Miss. Torborg Danira
# 50            51         0       3               Panula, Master. Juha Niilo
# 59            60         0       3       Goodwin, Master. William Frederick
# 63            64         0       3                    Skoog, Master. Harald
# 71            72         0       3               Goodwin, Miss. Lillian Amy
# 86            87         0       3                   Ford, Mr. William Neal
# 111          112         0       3                     Zabour, Miss. Hileni
# 114          115         0       3                    Attalah, Miss. Malake
# ...

# %% [markdown]
# ### **isin()** allows to check if the value is included in some sequence e.g [6, 7, 8, 5, 88]

# %%
df[df["Age"].isin([5, 10, 50])]
# Out:
#      PassengerId  Survived  Pclass  \
# 58            59         1       2
# 177          178         0       1
# 233          234         1       3
# 259          260         1       2
# 299          300         1       1
# 419          420         0       3
# 434          435         0       1
# 448          449         1       3
# 458          459         1       2
# 482          483         0       3
# 526          527         1       2
# 544          545         0       1
# 660          661         1       1
# 723          724         0       2
# 777          778         1       3
# 819          820         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 58                      West, Miss. Constance Mirium  female   5.0      1
# 177                       Isham, Miss. Ann Elizabeth  female  50.0      0
# 233                   Asplund, Miss. Lillian Gertrud  female   5.0      4
# ...

# %% [markdown]
# ### in pandas | is *OR* and & is *AND*

# %%
df[(df["Age"] == 5) | (df["Age"] == 10)]
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 58            59         1       2    West, Miss. Constance Mirium  female
# 233          234         1       3  Asplund, Miss. Lillian Gertrud  female
# 419          420         0       3       Van Impe, Miss. Catharina  female
# 448          449         1       3  Baclini, Miss. Marie Catherine  female
# 777          778         1       3   Emanuel, Miss. Virginia Ethel  female
# 819          820         0       3    Skoog, Master. Karl Thorsten    male
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 58    5.0      1      2  C.A. 34651  27.7500   NaN        S
# 233   5.0      4      2      347077  31.3875   NaN        S
# 419  10.0      0      2      345773  24.1500   NaN        S
# 448   5.0      2      1        2666  19.2583   NaN        C
# 777   5.0      0      0      364516  12.4750   NaN        S
# 819  10.0      3      2      347088  27.9000   NaN        S

# %% [markdown]
# ## return bool mask. checks if the row has a value. if so returns True

# %%
df["Age"].notna()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: Age, Length: 891, dtype: bool

# %% [markdown]
# ### This expression with use of .notna() return only those records which do NOT have NaN (Null)

# %%
df[df["Cabin"].notna()]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### This expression with use of **.isna()** will return only those records which HAVE NaN (Null)

# %%
df[df["Cabin"].isna()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# ## the amount of is null values

# %%
df["Age"].isna().sum()
# Out:
# np.int64(177)

# %% [markdown]
# using loc[] to filter by giving it a bool mask

# %%
df.loc[df["Age"].notna(), "Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 885                 Rice, Mrs. William (Margaret Norton)
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 714, dtype: object

# %%
df.sort_values("Age").head(5)
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 78            79         1       2    Caldwell, Master. Alden Gates    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 803  0.42      0      1    2625   8.5167   NaN        C
# 755  0.67      1      1  250649  14.5000   NaN        S
# 644  0.75      2      1    2666  19.2583   NaN        C
# 469  0.75      2      1    2666  19.2583   NaN        C
# 78   0.83      0      2  248738  29.0000   NaN        S

# %% [markdown]
# ## ascending= Sorting in Descending order for Age, and in descending order for Name

# %%
df.sort_values(["Age", "Name"], ascending=[False, True]).head(5)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q

# %% [markdown]
# ## copying dataframes
# use deep to copy all the elements not just the link.

# %%
df2 = df.copy(deep=True)

# %% [markdown]
# ## Concatenation two dataframes

# %%
cdf1 = pd.concat([df, df2])

# %%
cdf1.shape
# Out:
# (1782, 12)

# %%
df2.shape
# Out:
# (891, 12)

# %%
df.shape
# Out:
# (891, 12)

# %%
cdf1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## use axis to concatenate df along columns. **Reminds me of** joining two tables
# **axis=1: This is the crucial part that specifies how the concatenation should happen.**
# - axis=0 would concatenate along the index (vertically, adding rows).
# - axis=1 concatenates along the columns (horizontally, adding columns). This means it will try to "glue" the columns of df2 to the right side of df.

# %%
cdf2 = pd.concat([df, df2], axis=1)

# %%
cdf2.shape
# Out:
# (891, 24)

# %%
cdf2
# Out:
#      PassengerId  Survived Pclass  \
# 0              1         0      3
# 1              2         1      1
# 2              3         1      3
# 3              4         1      1
# 4              5         0      3
# ..           ...       ...    ...
# 886          887         0      2
# 887          888         1      1
# 888          889         0      3
# 889          890         1      1
# 890          891         0      3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
mdf = pd.DataFrame(index=df.index)
mdf["PassengerId"] = df["PassengerId"]
mdf["evenID"] = mdf["PassengerId"].apply(lambda x: x % 2 == 0)

# %%
mdf
# Out:
#      PassengerId  evenID
# 0              1   False
# 1              2    True
# 2              3   False
# 3              4    True
# 4              5   False
# ..           ...     ...
# 886          887   False
# 887          888    True
# 888          889   False
# 889          890    True
# 890          891   False
#
# [891 rows x 2 columns]

# %% [markdown]
# ## JOIN using **merge()**. takes two args, and the join method

# %%
pd.merge(df, mdf, how="inner")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Analtical functions. Аналитические функции

# %%
df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %% [markdown]
# ## count values

# %%
df["Age"].count()
# Out:
# np.int64(714)

# %% [markdown]
# # Mean and Median

# %%
df["Age"].mean(), df["Age"].median()
# Out:
# (np.float64(29.69911764705882), np.float64(28.0))

# %%
df["Age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df.groupby("Sex")["Age"].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
df.groupby("Sex")["Age"].describe()
# Out:
#         count       mean        std   min   25%   50%   75%   max
# Sex
# female  261.0  27.915709  14.110146  0.75  18.0  27.0  37.0  63.0
# male    453.0  30.726645  14.678201  0.42  21.0  29.0  39.0  80.0

# %% [markdown]
# ### .agg() lets you to передать multiple agregate foos.

# %%
df.groupby(["Sex", "Survived"])["Age"].agg(["mean", "median"])
# Out:
#                       mean  median
# Sex    Survived
# female 0         25.046875    24.5
#        1         28.847716    28.0
# male   0         31.618056    29.0
#        1         27.276022    28.0
